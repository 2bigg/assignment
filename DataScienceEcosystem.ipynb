# %% [markdown]
# ![2-title.png](attachment:0a8862f3-7f34-40cc-82b3-d799bbf7eff4.png)

# %% [markdown]
# ![3-intro.png](attachment:c83221b9-bf56-439a-b72c-df7bc3136f74.png)

# %% [markdown]
# ![10-objectives.png](attachment:aa2a8f1e-b826-4b52-bf4b-ee6f88426768.png)

# %% [markdown]
# ![5-dslibraries.png](attachment:623d656f-47d6-4898-a5af-3c823f5e1efe.png)

# %% [markdown]
# ![6-dstools.png](attachment:467cac1a-e5f3-4612-8bac-a2c297f9b8f5.png)

# %% [markdown]
# ![7-introarithmetic.png](attachment:879cc764-4212-46e2-9236-2656914eb4d2.png)

# %% [markdown]
# ![11-authordetails.png](attachment:e437f858-aa50-422d-95c9-fb06021faf92.png)

# %% [markdown]
# ![9-hourstominutes.png](attachment:ae266529-787c-4987-b321-655a08749785.png)
